# %% [markdown]
# # OCT Numerical model

# %%
import miepython
import numpy as np
import matplotlib.pyplot as plt
import DataProcessingOCT
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# %%
# Here some basic inputs
centre_wavelength = 800*10**(-9)
bandwidth_wavelength = 50e-9 # meter 
input_power = 0.001 # watt
integration_time = 1e-3 # seconds
alpha = 0.5 # intensity splitting ratio
num_samples = 1024

upsample = 8

# %%
# calculate some variables based on the initial parameters
kc = 2*np.pi/centre_wavelength
dk = bandwidth_wavelength *2*np.pi/centre_wavelength**2

#FWHM_k = bandwidth_wavelength*2*np.pi/centre_wavelength**2
sigma_k = dk/(2*np.sqrt(2*np.log(2)))

# minimum en maximum waardes van k
k_min = kc-1.5*dk
k_max = kc+1.5*dk

# het maken van de k_space
k_space = np.linspace(k_min,k_max,num_samples)

delta_k_space = k_space[1]-k_space[0]

# create the z_space
z_space = np.linspace(-0.5*np.pi/((k_max-k_min)/num_samples),0.5*np.pi/((k_max-k_min)/num_samples),num_samples)

# create the input signal in k space
signal_k_space = input_power*delta_k_space/np.sqrt(2*np.pi*sigma_k**2)*np.exp(-(k_space-kc)**2/(2*sigma_k**2))

# %%
# define some more parameters and retrieve the scattering efficiacy
z_surface = 200e-6

n_part = 1.38
n_med = 1.33
volume = 0.01

particle_diameter = 2000*10**(-9)

# number of particles 
Conc = volume/((4/3) * np.pi * (particle_diameter/2)**3)

a,Q,c,d = miepython.ez_mie(n_part,particle_diameter,centre_wavelength,n_med)

print('De scattering efficiacy is ',Q)
mu_s = Conc * Q * np.pi * (particle_diameter/2)**2 

L = 25e-6
D = 0.8e-3
P_NA = 0.5
N_iter = 100

number_of_particles = round(Conc*D*L**2)

particles_per_bin = number_of_particles*(z_space[1]-z_space[0])/D
R_part = P_NA * Q * np.pi*(particle_diameter/2)**2

print(number_of_particles)
# Out:
# De scattering efficiacy is  0.30153937437282
# 1194

# %%
zs = z_space
M = num_samples
zsurf = z_surface

# %% [markdown]
# # B-scan
#
# Create a B scan based on creating multiple A-scans and arranging them in an array.

# %%
# Define some parameters for the simulation
N_lim = 1
N_A_scans = 512   # number of A scans

# create the image array
speckle_image = np.zeros([int(M/2),N_A_scans])

# iterate over all a scans
for a_scan_num in range(N_A_scans):

    print('Calculating A Scan: ',a_scan_num)

    # create a new particle distribution for each a scan
    z_part = z_surface + np.random.uniform(0,1,number_of_particles)*D
    z_part = np.sort(z_part)

    # create an array with the count of all particles
    cnt = np.arange(number_of_particles)

    # calculate the transmission coefficient for each particle
    transm = (1-(Q*np.pi*(particle_diameter/2)**2/L**2))**(cnt)

    # define and create a phase factor for each particle
    phase_factors = np.zeros([num_samples,number_of_particles],dtype=complex)

    for a in np.arange(1,number_of_particles):
        phase_factors[:,a] = np.sqrt(R_part)*transm[a-1]*np.exp(1j*2*z_part[a]*k_space)

    phase_factors = np.sum(phase_factors,1)

    # calculate the fields due to the reference and the sample
    Ek_sample = np.sqrt(alpha*(1-alpha))*np.sqrt(signal_k_space)*phase_factors
    Ek_ref = np.sqrt(alpha*(1-alpha))*np.sqrt(signal_k_space)

    # using the fields calculate the intensity
    Ik_int = (Ek_sample+Ek_ref)*np.conj(Ek_sample+Ek_ref) - Ek_sample*np.conj(Ek_sample)-Ek_ref*np.conj(Ek_ref)

    # calculate the OCT signal
    OCT_signal = np.fft.ifftshift(np.fft.ifft(Ik_int))

    # place a scan in the matrix
    speckle_image[:,a_scan_num] = np.abs(OCT_signal[int(M/2):])
# Out:
# Calculating A Scan:  0
# Calculating A Scan:  1
# Calculating A Scan:  2
# Calculating A Scan:  3
# Calculating A Scan:  4
# Calculating A Scan:  5
# Calculating A Scan:  6
# Calculating A Scan:  7
# Calculating A Scan:  8
# Calculating A Scan:  9
# Calculating A Scan:  10
# Calculating A Scan:  11
# Calculating A Scan:  12
# Calculating A Scan:  13
# Calculating A Scan:  14
# Calculating A Scan:  15
# Calculating A Scan:  16
# Calculating A Scan:  17
# Calculating A Scan:  18
# Calculating A Scan:  19
# Calculating A Scan:  20
# Calculating A Scan:  21
# Calculating A Scan:  22
# Calculating A Scan:  23
# Calculating A Scan:  24
# Calculating A Scan:  25
# Calculating A Scan:  26
# Calculating A Scan:  27
# Calculating A Scan:  28
# Calculating A Scan:  29
# Calculating A Scan:  30
# Calculating A Scan:  31
# Calculating A Scan:  32
# Calculating A Scan:  33
# Calculating A Scan:  34
# Calculating A Scan:  35
# Calculating A Scan:  36
# Calculating A Scan:  37
# Calculating A Scan:  38
# Calculating A Scan:  39
# Calculating A Scan:  40
# Calculating A Scan:  41
# Calculating A Scan:  42
# Calculating A Scan:  43
# Calculating A Scan:  44
# Calculating A Scan:  45
# Calculating A Scan:  46
# Calculating A Scan:  47
# Calculating A Scan:  48
# Calculating A Scan:  49
# Calculating A Scan:  50
# Calculating A Scan:  51
# Calculating A Scan:  52
# Calculating A Scan:  53
# Calculating A Scan:  54
# Calculating A Scan:  55
# Calculating A Scan:  56
# Calculating A Scan:  57
# Calculating A Scan:  58
# Calculating A Scan:  59
# Calculating A Scan:  60
# Calculating A Scan:  61
# Calculating A Scan:  62
# Calculating A Scan:  63
# Calculating A Scan:  64
# Calculating A Scan:  65
# Calculating A Scan:  66
# Calculating A Scan:  67
# Calculating A Scan:  68
# Calculating A Scan:  69
# Calculating A Scan:  70
# Calculating A Scan:  71
# Calculating A Scan:  72
# Calculating A Scan:  73
# Calculating A Scan:  74
# Calculating A Scan:  75
# Calculating A Scan:  76
# Calculating A Scan:  77
# Calculating A Scan:  78
# Calculating A Scan:  79
# Calculating A Scan:  80
# Calculating A Scan:  81
# Calculating A Scan:  82
# Calculating A Scan:  83
# Calculating A Scan:  84
# Calculating A Scan:  85
# Calculating A Scan:  86
# Calculating A Scan:  87
# Calculating A Scan:  88
# Calculating A Scan:  89
# Calculating A Scan:  90
# Calculating A Scan:  91
# Calculating A Scan:  92
# Calculating A Scan:  93
# Calculating A Scan:  94
# Calculating A Scan:  95
# Calculating A Scan:  96
# Calculating A Scan:  97
# Calculating A Scan:  98
# Calculating A Scan:  99
# Calculating A Scan:  100
# Calculating A Scan:  101
# Calculating A Scan:  102
# Calculating A Scan:  103
# Calculating A Scan:  104
# Calculating A Scan:  105
# Calculating A Scan:  106
# Calculating A Scan:  107
# Calculating A Scan:  108
# Calculating A Scan:  109
# Calculating A Scan:  110
# Calculating A Scan:  111
# Calculating A Scan:  112
# Calculating A Scan:  113
# Calculating A Scan:  114
# Calculating A Scan:  115
# Calculating A Scan:  116
# Calculating A Scan:  117
# Calculating A Scan:  118
# Calculating A Scan:  119
# Calculating A Scan:  120
# Calculating A Scan:  121
# Calculating A Scan:  122
# Calculating A Scan:  123
# Calculating A Scan:  124
# Calculating A Scan:  125
# Calculating A Scan:  126
# Calculating A Scan:  127
# Calculating A Scan:  128
# Calculating A Scan:  129
# Calculating A Scan:  130
# Calculating A Scan:  131
# Calculating A Scan:  132
# Calculating A Scan:  133
# Calculating A Scan:  134
# Calculating A Scan:  135
# Calculating A Scan:  136
# Calculating A Scan:  137
# Calculating A Scan:  138
# Calculating A Scan:  139
# Calculating A Scan:  140
# Calculating A Scan:  141
# Calculating A Scan:  142
# Calculating A Scan:  143
# Calculating A Scan:  144
# Calculating A Scan:  145
# Calculating A Scan:  146
# Calculating A Scan:  147
# Calculating A Scan:  148
# Calculating A Scan:  149
# Calculating A Scan:  150
# Calculating A Scan:  151
# Calculating A Scan:  152
# Calculating A Scan:  153
# Calculating A Scan:  154
# Calculating A Scan:  155
# Calculating A Scan:  156
# Calculating A Scan:  157
# Calculating A Scan:  158
# Calculating A Scan:  159
# Calculating A Scan:  160
# Calculating A Scan:  161
# Calculating A Scan:  162
# Calculating A Scan:  163
# Calculating A Scan:  164
# Calculating A Scan:  165
# Calculating A Scan:  166
# Calculating A Scan:  167
# Calculating A Scan:  168
# Calculating A Scan:  169
# Calculating A Scan:  170
# Calculating A Scan:  171
# Calculating A Scan:  172
# Calculating A Scan:  173
# Calculating A Scan:  174
# Calculating A Scan:  175
# Calculating A Scan:  176
# Calculating A Scan:  177
# Calculating A Scan:  178
# Calculating A Scan:  179
# Calculating A Scan:  180
# Calculating A Scan:  181
# Calculating A Scan:  182
# Calculating A Scan:  183
# Calculating A Scan:  184
# Calculating A Scan:  185
# Calculating A Scan:  186
# Calculating A Scan:  187
# Calculating A Scan:  188
# Calculating A Scan:  189
# Calculating A Scan:  190
# Calculating A Scan:  191
# Calculating A Scan:  192
# Calculating A Scan:  193
# Calculating A Scan:  194
# Calculating A Scan:  195
# Calculating A Scan:  196
# Calculating A Scan:  197
# Calculating A Scan:  198
# Calculating A Scan:  199
# Calculating A Scan:  200
# Calculating A Scan:  201
# Calculating A Scan:  202
# Calculating A Scan:  203
# Calculating A Scan:  204
# Calculating A Scan:  205
# Calculating A Scan:  206
# Calculating A Scan:  207
# Calculating A Scan:  208
# Calculating A Scan:  209
# Calculating A Scan:  210
# Calculating A Scan:  211
# Calculating A Scan:  212
# Calculating A Scan:  213
# Calculating A Scan:  214
# Calculating A Scan:  215
# Calculating A Scan:  216
# Calculating A Scan:  217
# Calculating A Scan:  218
# Calculating A Scan:  219
# Calculating A Scan:  220
# Calculating A Scan:  221
# Calculating A Scan:  222
# Calculating A Scan:  223
# Calculating A Scan:  224
# Calculating A Scan:  225
# Calculating A Scan:  226
# Calculating A Scan:  227
# Calculating A Scan:  228
# Calculating A Scan:  229
# Calculating A Scan:  230
# Calculating A Scan:  231
# Calculating A Scan:  232
# Calculating A Scan:  233
# Calculating A Scan:  234
# Calculating A Scan:  235
# Calculating A Scan:  236
# Calculating A Scan:  237
# Calculating A Scan:  238
# Calculating A Scan:  239
# Calculating A Scan:  240
# Calculating A Scan:  241
# Calculating A Scan:  242
# Calculating A Scan:  243
# Calculating A Scan:  244
# Calculating A Scan:  245
# Calculating A Scan:  246
# Calculating A Scan:  247
# Calculating A Scan:  248
# Calculating A Scan:  249
# Calculating A Scan:  250
# Calculating A Scan:  251
# Calculating A Scan:  252
# Calculating A Scan:  253
# Calculating A Scan:  254
# Calculating A Scan:  255
# Calculating A Scan:  256
# Calculating A Scan:  257
# Calculating A Scan:  258
# Calculating A Scan:  259
# Calculating A Scan:  260
# Calculating A Scan:  261
# Calculating A Scan:  262
# Calculating A Scan:  263
# Calculating A Scan:  264
# Calculating A Scan:  265
# Calculating A Scan:  266
# Calculating A Scan:  267
# Calculating A Scan:  268
# Calculating A Scan:  269
# Calculating A Scan:  270
# Calculating A Scan:  271
# Calculating A Scan:  272
# Calculating A Scan:  273
# Calculating A Scan:  274
# Calculating A Scan:  275
# Calculating A Scan:  276
# Calculating A Scan:  277
# Calculating A Scan:  278
# Calculating A Scan:  279
# Calculating A Scan:  280
# Calculating A Scan:  281
# Calculating A Scan:  282
# Calculating A Scan:  283
# Calculating A Scan:  284
# Calculating A Scan:  285
# Calculating A Scan:  286
# Calculating A Scan:  287
# Calculating A Scan:  288
# Calculating A Scan:  289
# Calculating A Scan:  290
# Calculating A Scan:  291
# Calculating A Scan:  292
# Calculating A Scan:  293
# Calculating A Scan:  294
# Calculating A Scan:  295
# Calculating A Scan:  296
# Calculating A Scan:  297
# Calculating A Scan:  298
# Calculating A Scan:  299
# Calculating A Scan:  300
# Calculating A Scan:  301
# Calculating A Scan:  302
# Calculating A Scan:  303
# Calculating A Scan:  304
# Calculating A Scan:  305
# Calculating A Scan:  306
# Calculating A Scan:  307
# Calculating A Scan:  308
# Calculating A Scan:  309
# Calculating A Scan:  310
# Calculating A Scan:  311
# Calculating A Scan:  312
# Calculating A Scan:  313
# Calculating A Scan:  314
# Calculating A Scan:  315
# Calculating A Scan:  316
# Calculating A Scan:  317
# Calculating A Scan:  318
# Calculating A Scan:  319
# Calculating A Scan:  320
# Calculating A Scan:  321
# Calculating A Scan:  322
# Calculating A Scan:  323
# Calculating A Scan:  324
# Calculating A Scan:  325
# Calculating A Scan:  326
# Calculating A Scan:  327
# Calculating A Scan:  328
# Calculating A Scan:  329
# Calculating A Scan:  330
# Calculating A Scan:  331
# Calculating A Scan:  332
# Calculating A Scan:  333
# Calculating A Scan:  334
# Calculating A Scan:  335
# Calculating A Scan:  336
# Calculating A Scan:  337
# Calculating A Scan:  338
# Calculating A Scan:  339
# Calculating A Scan:  340
# Calculating A Scan:  341
# Calculating A Scan:  342
# Calculating A Scan:  343
# Calculating A Scan:  344
# Calculating A Scan:  345
# Calculating A Scan:  346
# Calculating A Scan:  347
# Calculating A Scan:  348
# Calculating A Scan:  349
# Calculating A Scan:  350
# Calculating A Scan:  351
# Calculating A Scan:  352
# Calculating A Scan:  353
# Calculating A Scan:  354
# Calculating A Scan:  355
# Calculating A Scan:  356
# Calculating A Scan:  357
# Calculating A Scan:  358
# Calculating A Scan:  359
# Calculating A Scan:  360
# Calculating A Scan:  361
# Calculating A Scan:  362
# Calculating A Scan:  363
# Calculating A Scan:  364
# Calculating A Scan:  365
# Calculating A Scan:  366
# Calculating A Scan:  367
# Calculating A Scan:  368
# Calculating A Scan:  369
# Calculating A Scan:  370
# Calculating A Scan:  371
# Calculating A Scan:  372
# Calculating A Scan:  373
# Calculating A Scan:  374
# Calculating A Scan:  375
# Calculating A Scan:  376
# Calculating A Scan:  377
# Calculating A Scan:  378
# Calculating A Scan:  379
# Calculating A Scan:  380
# Calculating A Scan:  381
# Calculating A Scan:  382
# Calculating A Scan:  383
# Calculating A Scan:  384
# Calculating A Scan:  385
# Calculating A Scan:  386
# Calculating A Scan:  387
# Calculating A Scan:  388
# Calculating A Scan:  389
# Calculating A Scan:  390
# Calculating A Scan:  391
# Calculating A Scan:  392
# Calculating A Scan:  393
# Calculating A Scan:  394
# Calculating A Scan:  395
# Calculating A Scan:  396
# Calculating A Scan:  397
# Calculating A Scan:  398
# Calculating A Scan:  399
# Calculating A Scan:  400
# Calculating A Scan:  401
# Calculating A Scan:  402
# Calculating A Scan:  403
# Calculating A Scan:  404
# Calculating A Scan:  405
# Calculating A Scan:  406
# Calculating A Scan:  407
# Calculating A Scan:  408
# Calculating A Scan:  409
# Calculating A Scan:  410
# Calculating A Scan:  411
# Calculating A Scan:  412
# Calculating A Scan:  413
# Calculating A Scan:  414
# Calculating A Scan:  415
# Calculating A Scan:  416
# Calculating A Scan:  417
# Calculating A Scan:  418
# Calculating A Scan:  419
# Calculating A Scan:  420
# Calculating A Scan:  421
# Calculating A Scan:  422
# Calculating A Scan:  423
# Calculating A Scan:  424
# Calculating A Scan:  425
# Calculating A Scan:  426
# Calculating A Scan:  427
# Calculating A Scan:  428
# Calculating A Scan:  429
# Calculating A Scan:  430
# Calculating A Scan:  431
# Calculating A Scan:  432
# Calculating A Scan:  433
# Calculating A Scan:  434
# Calculating A Scan:  435
# Calculating A Scan:  436
# Calculating A Scan:  437
# Calculating A Scan:  438
# Calculating A Scan:  439
# Calculating A Scan:  440
# Calculating A Scan:  441
# Calculating A Scan:  442
# Calculating A Scan:  443
# Calculating A Scan:  444
# Calculating A Scan:  445
# Calculating A Scan:  446
# Calculating A Scan:  447
# Calculating A Scan:  448
# Calculating A Scan:  449
# Calculating A Scan:  450
# Calculating A Scan:  451
# Calculating A Scan:  452
# Calculating A Scan:  453
# Calculating A Scan:  454
# Calculating A Scan:  455
# Calculating A Scan:  456
# Calculating A Scan:  457
# Calculating A Scan:  458
# Calculating A Scan:  459
# Calculating A Scan:  460
# Calculating A Scan:  461
# Calculating A Scan:  462
# Calculating A Scan:  463
# Calculating A Scan:  464
# Calculating A Scan:  465
# Calculating A Scan:  466
# Calculating A Scan:  467
# Calculating A Scan:  468
# Calculating A Scan:  469
# Calculating A Scan:  470
# Calculating A Scan:  471
# Calculating A Scan:  472
# Calculating A Scan:  473
# Calculating A Scan:  474
# Calculating A Scan:  475
# Calculating A Scan:  476
# Calculating A Scan:  477
# Calculating A Scan:  478
# Calculating A Scan:  479
# Calculating A Scan:  480
# Calculating A Scan:  481
# Calculating A Scan:  482
# Calculating A Scan:  483
# Calculating A Scan:  484
# Calculating A Scan:  485
# Calculating A Scan:  486
# Calculating A Scan:  487
# Calculating A Scan:  488
# Calculating A Scan:  489
# Calculating A Scan:  490
# Calculating A Scan:  491
# Calculating A Scan:  492
# Calculating A Scan:  493
# Calculating A Scan:  494
# Calculating A Scan:  495
# Calculating A Scan:  496
# Calculating A Scan:  497
# Calculating A Scan:  498
# Calculating A Scan:  499
# Calculating A Scan:  500
# Calculating A Scan:  501
# Calculating A Scan:  502
# Calculating A Scan:  503
# Calculating A Scan:  504
# Calculating A Scan:  505
# Calculating A Scan:  506
# Calculating A Scan:  507
# Calculating A Scan:  508
# Calculating A Scan:  509
# Calculating A Scan:  510
# Calculating A Scan:  511

# %%
# Plot the image using the plotting tools in DataProcessingOCT
import DataProcessingOCT

fig1,ax=DataProcessingOCT.plot_Bscan_image(speckle_image,dBlevel=25,title='Speckle Image')

# %% [markdown]
# # Flow in a channel over multiple B-scans

# %%
# set some parameters for the measurement and the flow
speed_of_flow = 2e-3 # meters per second
a_scan_rate = 5e3 # hertz
N_A_scans = 512   # number of A scans per B scan
N_B_scans = 50 # number of b scans

# from this calculate the b scan time:
b_scan_time = 1/a_scan_rate*N_A_scans

# otherwise set the b scan time manually
b_scan_time = b_scan_time  # in that case change this

print('B scan time is: ',b_scan_time)

# from flow speed to pixels per b scan
pixels_per_second = round(speed_of_flow * 1/L)
pixels_per_b_scan = round(pixels_per_second*b_scan_time)

print("The amount of pixels moved after a b scan is: ",pixels_per_b_scan)

# define the location of the flow channel in the sample
z_min_channel = 0.4e-3
z_max_channel = 0.8e-3

# create an array for all particle positions over all scans
particle_positions = np.zeros([N_A_scans,number_of_particles,N_B_scans])

# number of particles per area:
num_part1 = int(round(number_of_particles/D*(z_min_channel-z_surface)))  # number of particles in area 1 calculated by size
num_part2 = int(round(number_of_particles/D*(z_max_channel-z_min_channel)))+1 # the plus one is due to rounding down errors
num_part3 = int(round(number_of_particles/D*(D+z_surface-z_max_channel)))

# for area 1,2 en 3 allocate the positions randomly
# create arrays for all positions in all a scans
z_particles_1 = np.zeros([N_A_scans,num_part1])
z_particles_2 = np.zeros([N_A_scans,num_part2,N_B_scans])
z_particles_3 = np.zeros([N_A_scans,num_part3])

# create the first particle positions
for A_scan in range(N_A_scans):

    z_particles_1[A_scan,:] = z_surface + np.random.uniform(0,1,num_part1)*(z_min_channel-z_surface)
    
    z_particles_3[A_scan,:] = z_max_channel + np.random.uniform(0,1,num_part3)*(D+z_surface-z_max_channel)

    # create the particles in the channel at t=0
    z_particles_2[A_scan,:,0] = z_min_channel + np.random.uniform(0,1,num_part2)*(z_max_channel-z_min_channel)
    
    # allocate the particle positions at t=0
    particle_positions[A_scan,:,0] = np.sort(np.concatenate((z_particles_1[A_scan,:],z_particles_2[A_scan,:,0],z_particles_3[A_scan,:])))


# create the effect of flow in over all b scans
for B_scan in range(1,N_B_scans):
    # for every b scan shift the speckle in the channel
    for A_scan in range(pixels_per_b_scan*B_scan):
        part_2 = z_min_channel + np.random.uniform(0,1,num_part2)*(z_max_channel-z_min_channel)
        particle_positions[A_scan,:,B_scan] = np.sort(np.concatenate((z_particles_1[A_scan,:],part_2,z_particles_3[A_scan,:])))


    for A_scan in range(pixels_per_b_scan*B_scan,N_A_scans):

        # create the particle positions for each a scan
        part_2 = z_particles_2[A_scan-pixels_per_b_scan*B_scan,:,0]

        # set the particle positions
        particle_positions[A_scan,:,B_scan] = np.sort(np.concatenate((z_particles_1[A_scan,:],part_2,z_particles_3[A_scan,:])))

# %%
plt.imshow(particle_positions[:,:,1])

# %%
# define the function that creates a speckle image based on the particle positions

def create_speckle_image(particle_positions, N_A_scans):

    # create the image array:
    speckle_image = np.zeros([int(M/2),N_A_scans])

    # calculate the a scans
    for a_scan_num in range(N_A_scans):

        # retrieve the particle positions
        z_part = particle_positions[a_scan_num,:]

        # create an array with the count of all particles
        cnt = np.arange(number_of_particles)

        # calculate the transmission coefficient for each particle
        transm = (1-(Q*np.pi*(particle_diameter/2)**2/L**2))**(cnt)

        # define and create a phase factor for each particle
        phase_factors = np.zeros([num_samples,number_of_particles],dtype=complex)

        for a in np.arange(1,number_of_particles):
            phase_factors[:,a] = np.sqrt(R_part)*transm[a-1]*np.exp(1j*2*z_part[a]*k_space)

        phase_factors = np.sum(phase_factors,1)

        # calculate the fields due to the reference and the sample
        Ek_sample = np.sqrt(alpha*(1-alpha))*np.sqrt(signal_k_space)*phase_factors
        Ek_ref = np.sqrt(alpha*(1-alpha))*np.sqrt(signal_k_space)

        # using the fields calculate the intensity
        Ik_int = (Ek_sample+Ek_ref)*np.conj(Ek_sample+Ek_ref) - Ek_sample*np.conj(Ek_sample)-Ek_ref*np.conj(Ek_ref)

        # calculate the OCT signal
        OCT_signal = np.fft.ifftshift(np.fft.ifft(Ik_int))

        # place a scan in the matrix
        speckle_image[:,a_scan_num] = np.abs(OCT_signal[int(M/2):])

    return speckle_image

# %%
# create the timeseries data
image_timeseries = np.zeros([int(M/2),N_A_scans, N_B_scans])
for B_scan in range(N_B_scans):
    print(B_scan)
    image_timeseries[:,:,B_scan] = create_speckle_image(particle_positions[:,:,B_scan],N_A_scans)

# %%
# save the image data
#image_timeseries.shape
#np.save("timeseries512-512-50.npy",image_timeseries)

# %%
# plot the average over the timeseries of the data
image_average = np.average(image_timeseries,2)
fig1,ax=DataProcessingOCT.plot_Bscan_image(image_average,dBlevel=25,title='Average of timeseries flow data')
plt.show()
